# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
# %matplotlib notebook

df = pd.read_csv('acc_dat.csv')
df = df[df['STATE/UT'] == 'Delhi (Ut)']
df.drop(['STATE/UT', 'Total'], axis = 1, inplace = True)
df = df.iloc[9:]
df.columns = ['Year', '3AM', '6AM', '9AM', '12PM', '3PM', '6PM', '9PM', '12AM']

df.set_index('Year',inplace = True)

df = df.T

df.index.names = ['Timing']

df
# Out:
# Year    2010  2011  2012  2013  2014
# Timing
# 3AM      597   607   638   764   757
# 6AM      502   535   509   662   581
# 9AM      778   794   648   718   867
# 12PM     905   936   872   828   925
# 3PM      928   963   920   896   909
# 6PM      998  1087  1039   981  1208
# 9PM     1234  1100  1131  1341  1502
# 12AM    1278  1258  1180  1379  1561

# %%
df.plot.line()
plt.ylabel('Number of Accidents')
plt.title('Frequency of Accidents during different parts of the day in New Delhi')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Frequency of Accidents during different parts of the day in New Delhi')
